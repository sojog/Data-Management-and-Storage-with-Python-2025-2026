# %% [markdown]
# # pip install requests

# %%
import requests

# %%
URL = "https://www.loto.ro/?p=3872"

# %%
response = requests.get(URL)

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html> <!--[if !(IE 6) | !(IE 7) | !(IE 8)  ]><!--><html lang="ro-RO" class="no-js"> <!--<![endif]--><head><meta charset="UTF-8" /><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0"><meta name="theme-color" content="#0b8418"/><link rel="profile" href="https://gmpg.org/xfn/11" /> <script defer src="data:text/javascript;base64,..."></script> <title>Rezultate extrageri &#8211; Loteria Romana</title><meta name=\'robots\' content=\'max-image-preview:large\' /><link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' /><link rel="alternate" type="application/rss+xml" title="Loteria Romana &raquo; Flux" href="https://www.loto.ro/?feed=rss2" /><link rel="alternate" type="application/rss+xml" title="Loteria Romana &raquo; Flux comentarii" href="https://www.loto.ro/?feed=comments-rss2" /><link rel="alternate" type="application/rss+xml" title="Flux comentarii Loteria Romana &raquo; Rezultate extrageri" href="https://www.loto.ro/?feed
# ...

# %%
with open("08.response.html", "w") as file_writer:
    file_writer.write(response.text)
