# %%
with open("03.suma.txt", "r") as file_reader:
    continut = file_reader.read()

# %%
continut
# Out:
# '1\n2\n3\n3\n4\n5\n6\n7'

# %%
print(continut)
# Out:
# 1
# 2
# 3
# 3
# 4
# 5
# 6
# 7

# %%
type(continut)
# Out:
# str

# %%
numere_stringuri = continut.split("\n")
numere_stringuri
# Out:
# ['1', '2', '3', '3', '4', '5', '6', '7']

# %%
suma = 0 
for i in numere_stringuri:
    suma += int(i)
print(suma)
# Out:
# 31

# %%
with open("03.suma.txt", "r") as file_reader:
    continut = file_reader.readline()

print(continut)
# Out:
# 1

# %%
with open("03.suma.txt", "r") as file_reader:
    continut = file_reader.readlines()

print(continut)
# Out:
# ['1\n', '2\n', '3\n', '3\n', '4\n', '5\n', '6\n', '7']
