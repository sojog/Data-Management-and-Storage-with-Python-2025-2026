# %%
import requests

# %%
URL = "https://api.open-meteo.com/v1/forecast"

# %%
params = {
    "latitude":44.4268,
    "longitude":26.1025,
    "current":"temperature_2m"
}

# %%
response = requests.get(URL, params=params)
response
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# {'latitude': 44.4375, 'longitude': 26.125, 'generationtime_ms': 0.029087066650390625, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 72.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C'}, 'current': {'time': '2026-01-13T18:15', 'interval': 900, 'temperature_2m': -4.4}}

# %%
from pprint import pprint

# %%
pprint(response.json())
# Out:
# {'current': {'interval': 900,
#              'temperature_2m': -4.4,
#              'time': '2026-01-13T18:15'},
#  'current_units': {'interval': 'seconds',
#                    'temperature_2m': '°C',
#                    'time': 'iso8601'},
#  'elevation': 72.0,
#  'generationtime_ms': 0.029087066650390625,
#  'latitude': 44.4375,
#  'longitude': 26.125,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'utc_offset_seconds': 0}

# %%
response.json()['current']['temperature_2m']
# Out:
# -4.4

# %%
response.url
# Out:
# 'https://api.open-meteo.com/v1/forecast?latitude=44.4268&longitude=26.1025&current=temperature_2m'

# %%
"https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&current=temperature_2m"
# Out:
# 'https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&current=temperature_2m'
