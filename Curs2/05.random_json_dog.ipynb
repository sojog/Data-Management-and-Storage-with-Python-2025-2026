# %%
import requests

# %%
URL = "https://random.dog/woof.json"

# %%
response = requests.get(URL)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"fileSizeBytes":83789,"url":"https://random.dog/23d8e5ba-adc6-4a90-9172-bfc9570d57e7.jpg"}'

# %%
response.content
# Out:
# b'{"fileSizeBytes":83789,"url":"https://random.dog/23d8e5ba-adc6-4a90-9172-bfc9570d57e7.jpg"}'

# %%
import json

# %%
json_parsed = json.loads(response.text)
json_parsed
# Out:
# {'fileSizeBytes': 83789,
#  'url': 'https://random.dog/23d8e5ba-adc6-4a90-9172-bfc9570d57e7.jpg'}

# %%
type(json_parsed)
# Out:
# dict

# %%
json_parsed["url"]
# Out:
# 'https://random.dog/23d8e5ba-adc6-4a90-9172-bfc9570d57e7.jpg'

# %%
with open("json_response.json", "w") as file_writer:
    file_writer.write(response.text)

# %%
with open("json_response.json", "r") as file_reader:
    json_citit_string =  file_reader.read()

print(json_citit_string)
print(type(json_citit_string))
# Out:
# {
#     "fileSizeBytes": 83789,
#     "url": "https://random.dog/23d8e5ba-adc6-4a90-9172-bfc9570d57e7.jpg"
# }
# <class 'str'>

# %%
with open("json_response.json", "r") as file_reader:
    json_citit_dict = json.load(file_reader)


print(json_citit_dict)
print(type(json_citit_dict))
# Out:
# {'fileSizeBytes': 83789, 'url': 'https://random.dog/23d8e5ba-adc6-4a90-9172-bfc9570d57e7.jpg'}
# <class 'dict'>
