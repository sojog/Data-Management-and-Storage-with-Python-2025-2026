# %%
import requests

# %%
URL = "https://random.dog/"

# %%
response = requests.get(URL)
response.content
# Out:
# b'<!DOCTYPE html>\n<html>\n\n<head>\n    <meta name="viewport" content="initial-scale=1">\n    <meta name="description" content="Hello World, This Is Dog">\n    <meta name="author" content="AdenFlorian">\n    <title>random.dog</title>\n    <link rel="icon" href="favicon.ico">\n    <style>\n        body {\n            font-family: sans-serif;\n            margin: 0;\n            height: 100vh;\n        }\n\n        #main-div {\n            text-align: center;\n            height: 100vh;\n            margin: 0;\n        }\n\n        header {\n            height: 10%;\n            display: flex;\n            flex-direction: column;\n            justify-content: center;\n        }\n\n        h3 {\n            padding: 20px;\n            margin: 0;\n            font-size: 3vh;\n        }\n\n        #img-div {\n            height: 80%;\n            display: flex;\n            flex-direction: column;\n            justify-content: center;\n        }\n\n        #img-div div {\n            max
# ...

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta name="viewport" content="initial-scale=1">
#     <meta name="description" content="Hello World, This Is Dog">
#     <meta name="author" content="AdenFlorian">
#     <title>random.dog</title>
#     <link rel="icon" href="favicon.ico">
#     <style>
#         body {
#             font-family: sans-serif;
#             margin: 0;
#             height: 100vh;
#         }
#
#         #main-div {
#             text-align: center;
#             height: 100vh;
#             margin: 0;
#         }
#
#         header {
#             height: 10%;
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#         }
#
#         h3 {
#             padding: 20px;
#             margin: 0;
#             font-size: 3vh;
#         }
#
#         #img-div {
#             height: 80%;
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#         }
#
# ...

# %%
with open("dog_page.html", "w") as file_writer:
    file_writer.write(response.text)
