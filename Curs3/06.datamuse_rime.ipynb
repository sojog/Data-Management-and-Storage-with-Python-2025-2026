# %%
import requests

# %%
URL = "https://api.datamuse.com/words"

# %%
# toate cuvintele care sunt sinonime cu women
params = {
    "sl": "beautiful"
}
response = requests.get(URL, params=params)

# %%
from pprint import pprint

# %%
pprint(response.json())
# Out:
# [{'numSyllables': 3, 'score': 100, 'word': 'beautiful'},
#  {'numSyllables': 3, 'score': 100, 'word': 'beautifull'},
#  {'numSyllables': 3, 'score': 82, 'word': 'beautify'},
#  {'numSyllables': 3, 'score': 80, 'word': 'beautifully'},
#  {'numSyllables': 2, 'score': 80, 'word': 'butyl'},
#  {'numSyllables': 4, 'score': 80, 'word': 'beautiful eyes'},
#  {'numSyllables': 4, 'score': 80, 'word': 'beautiful day'},
#  {'numSyllables': 4, 'score': 80, 'word': 'unbeautiful'},
#  {'numSyllables': 3, 'score': 80, 'word': 'beautifies'},
#  {'numSyllables': 4, 'score': 80, 'word': 'so beautiful'},
#  {'numSyllables': 4, 'score': 80, 'word': 'beautifier'},
#  {'numSyllables': 4, 'score': 80, 'word': 'beautiful boy'},
#  {'numSyllables': 3, 'score': 78, 'word': 'pitiful'},
#  {'numSyllables': 4, 'score': 78, 'word': 'beautifying'},
#  {'numSyllables': 2, 'score': 77, 'word': 'beutel'},
#  {'numSyllables': 3, 'score': 75, 'word': 'beautified'},
#  {'numSyllables': 3, 'score': 75, 'word': 'blue waffle'},
#  {'numSyllables': 2, 'score': 75, 'word': 'bateful'},
#  {'numSyllables': 3, 'score': 75, 'word': 'bitterful'},
#  {'numSyllables': 2, 'score': 75, 'word': 'boatful'},
#  {'numSyllables': 3, 'score': 75, 'word': 'bottleful'},
#  {'numSyllables': 2, 'score': 75, 'word': 'bretful'},
#  {'numSyllables': 3, 'score': 75, 'word': 'battleful'},
#  {'numSyllables': 3, 'score': 75, 'word': 'butea'},
#  {'numSyllables': 3, 'score': 72, 'word': 'bountiful'},
#  {'numSyllables': 3, 'score': 72, 'word': 'blue devil'},
#  {'numSyllables': 3, 'score': 72, 'word': 'beta fish'},
#  {'numSyllables': 3, 'score': 72, 'word': 'betta fish'},
#  {'numSyllables': 2, 'score': 71, 'word': 'boastful'},
#  {'numSyllables': 4, 'score': 71, 'word': 'beatify'},
#  {'numSyllables': 2, 'score': 70, 'word': 'brutal'},
#  {'numSyllables': 3, 'score': 70, 'word': 'pedophile'},
#  {'numSyllables': 2, 'score': 70, 'word': 'bugle'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buil'},
#  {'numSyllables': 2, 'score': 70, 'word': 'bootle'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buton'},
#  {'numSyllables': 4, 'score': 70, 'word': 'beautifulness'},
#  {'numSyllables': 4, 'score': 70, 'word': 'beautiful girl'},
#  {'numSyllables': 2, 'score': 70, 'word': 'bugel'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buccal'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buell'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buffle'},
#  {'numSyllables': 3, 'score': 70, 'word': 'abuseful'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buta'},
#  {'numSyllables': 3, 'score': 70, 'word': 'bootable'},
#  {'numSyllables': 4, 'score': 70, 'word': 'beautiful game'},
#  {'numSyllables': 3, 'score': 70, 'word': 'butanol'},
#  {'numSyllables': 4, 'score': 70, 'word': 'your beautiful'},
#  {'numSyllables': 3, 'score': 70, 'word': 'buteo'},
#  {'numSyllables': 4, 'score': 70, 'word': 'beautiful soul'},
#  {'numSyllables': 2, 'score': 70, 'word': 'brutale'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buehrle'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buffel'},
#  {'numSyllables': 2, 'score': 70, 'word': 'bufa'},
#  {'numSyllables': 4, 'score': 70, 'word': 'beautiful thing'},
#  {'numSyllables': 2, 'score': 70, 'word': 'buechel'},
#  {'numSyllables': 4, 'score': 70, 'word': 'beautiful view'}]

# %%
type(response.json())
# Out:
# list

# %%
for obj in response.json():
    print(obj["word"])
# Out:
# beautiful
# beautifull
# beautify
# beautifully
# butyl
# beautiful eyes
# beautiful day
# unbeautiful
# beautifies
# so beautiful
# beautifier
# beautiful boy
# pitiful
# beautifying
# beutel
# beautified
# blue waffle
# bateful
# bitterful
# boatful
# bottleful
# bretful
# battleful
# butea
# bountiful
# blue devil
# beta fish
# betta fish
# boastful
# beatify
# brutal
# pedophile
# bugle
# buil
# bootle
# buton
# beautifulness
# beautiful girl
# bugel
# buccal
# buell
# buffle
# abuseful
# buta
# bootable
# beautiful game
# butanol
# your beautiful
# buteo
# beautiful soul
# brutale
# buehrle
# buffel
# bufa
# beautiful thing
# buechel
# beautiful view

# %%
rime = []

for obj in response.json():
    rime.append(obj["word"])

# %%
print(rime)
# Out:
# ['beautiful', 'beautifull', 'beautify', 'beautifully', 'butyl', 'beautiful eyes', 'beautiful day', 'unbeautiful', 'beautifies', 'so beautiful', 'beautifier', 'beautiful boy', 'pitiful', 'beautifying', 'beutel', 'beautified', 'blue waffle', 'bateful', 'bitterful', 'boatful', 'bottleful', 'bretful', 'battleful', 'butea', 'bountiful', 'blue devil', 'beta fish', 'betta fish', 'boastful', 'beatify', 'brutal', 'pedophile', 'bugle', 'buil', 'bootle', 'buton', 'beautifulness', 'beautiful girl', 'bugel', 'buccal', 'buell', 'buffle', 'abuseful', 'buta', 'bootable', 'beautiful game', 'butanol', 'your beautiful', 'buteo', 'beautiful soul', 'brutale', 'buehrle', 'buffel', 'bufa', 'beautiful thing', 'buechel', 'beautiful view']
