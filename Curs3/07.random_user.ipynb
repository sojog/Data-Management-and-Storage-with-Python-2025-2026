# %%
import requests

# %%
response = requests.get("https://randomuser.me/api/").json()
response
# Out:
# {'results': [{'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Hudson', 'last': 'Cooper'},
#    'location': {'street': {'number': 9327, 'name': 'Stafford Street'},
#     'city': 'Upper Hutt',
#     'state': 'Northland',
#     'country': 'New Zealand',
#     'postcode': 17340,
#     'coordinates': {'latitude': '53.8342', 'longitude': '-121.8840'},
#     'timezone': {'offset': '0:00',
#      'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#    'email': 'hudson.cooper@example.com',
#    'login': {'uuid': '717edd81-baad-4a34-b961-23f390e8a71f',
#     'username': 'happycat236',
#     'password': 'marco',
#     'salt': 'SOOZMnsS',
#     'md5': '6f49b50fb086b0a77e805886962c2ced',
#     'sha1': 'd4c275a3ba7781b05bbb0da28d1919224bb8f806',
#     'sha256': '778d73ad75df5eedefebdb780da89e6aa38e24ca99a286973b8ed40378cf5ff8'},
#    'dob': {'date': '1958-05-12T08:43:27.845Z', 'age': 67},
#    'registered': {'date': '2021-08-11T06:22:02.769Z', 'age': 4},
# ...

# %%
response["results"][0]["name"]
# Out:
# {'title': 'Mr', 'first': 'Hudson', 'last': 'Cooper'}

# %%
user = response["results"][0]["name"]

# %%
f"{user["title"]} {user["first"]} {user["last"]}"
# Out:
# 'Mr Hudson Cooper'

# %%
titles = {
    "Mr" : "Dl",
    'Monsieur' : "Dl",
    "Ms" : "Dna",
    "Miss" : "Dna",
    "Mrs" : "Dna",
}

# %%
user_title = titles.get(user["title"], "_")

# %%
f"{user_title} {user["first"]} {user["last"]}"
# Out:
# 'Dl Hudson Cooper'
