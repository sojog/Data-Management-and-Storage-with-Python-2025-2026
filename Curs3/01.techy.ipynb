# %%
import requests

# %%
BASE_URL = "https://techy-api.vercel.app/"

# %%
TEXT_PATH = "api/text"
JSON_PATH = "api/json"

# %%
response = requests.get(BASE_URL + TEXT_PATH)
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# 'Just use cryptography on the refraction resistance'

# %%
with open("techy.txt", "a") as file_writer:
    file_writer.write(response.text)
    file_writer.write("\n")

# %%
response2 = requests.get(BASE_URL + JSON_PATH)
response2
# Out:
# <Response [200]>

# %%
response2.text
# Out:
# '{"message":"Make sure to modulate the traffic intermittent"}'

# %%
response2.json(), type(response2.json())
# Out:
# ({'message': 'Make sure to modulate the traffic intermittent'}, dict)

# %%
response2.json()["message"]
# Out:
# 'Make sure to modulate the traffic intermittent'

# %%
with open("techy.txt", "a") as file_writer:
    file_writer.write(response2.json()["message"])
    file_writer.write("\n")

# %%
with open("jokes.json", "w") as file_writer:
    file_writer.write(response2.text)

# %%
response.headers['Content-Type']
# Out:
# 'text/html; charset=utf-8'

# %%
response2.headers['Content-Type']
# Out:
# 'application/json; charset=utf-8'

# %%
response.request.url
# Out:
# 'https://techy-api.vercel.app/api/text'

# %%
response2.request.url
# Out:
# 'https://techy-api.vercel.app/api/json'
