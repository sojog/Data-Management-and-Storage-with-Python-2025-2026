# %%
import requests

# %%
URL = "https://api.datamuse.com/words"

# %%
# toate cuvintele care sunt sinonime cu women
params = {
    "ml": "women"
}
response = requests.get(URL, params=params)

# %%
from pprint import pprint

# %%
pprint(response.json())
# Out:
# [{'score': 30046186,
#   'tags': ['n', 'results_type:primary_rel'],
#   'word': 'female'},
#  {'score': 20049284, 'tags': ['N', 'n'], 'word': 'females'},
#  {'score': 20049284, 'tags': ['n'], 'word': 'femmes'},
#  {'score': 20049284, 'tags': ['N'], 'word': 'mujeres'},
#  {'score': 20049284, 'tags': ['N', 'n'], 'word': 'wives'},
#  {'score': 20049283, 'tags': ['n'], 'word': 'gals'},
#  {'score': 20049282, 'tags': ['n'], 'word': 'girls'},
#  {'score': 20049281, 'tags': ['n'], 'word': 'dames'},
#  {'score': 20049280, 'tags': ['n'], 'word': 'damsels'},
#  {'score': 20049279, 'tags': ['n'], 'word': 'ladies'},
#  {'score': 20049277, 'tags': ['N'], 'word': 'mothers'},
#  {'score': 20049276, 'tags': ['n'], 'word': 'sisters'},
#  {'score': 20049275, 'tags': ['n'], 'word': 'wenches'},
#  {'score': 20049274, 'tags': ['n'], 'word': 'heroines'},
#  {'score': 20049273, 'tags': ['n'], 'word': 'maidens'},
#  {'score': 20049272, 'tags': ['n'], 'word': 'lasses'},
#  {'score': 20049271, 'tags': ['n'], 'word': 'womankind'},
#  {'score': 20049270, 'tags': ['n'], 'word': 'matrons'},
#  {'score': 20049268, 'tags': ['n', 'adj'], 'word': 'distaff'},
#  {'score': 20049267, 'tags': ['n'], 'word': 'chicks'},
#  {'score': 20049266, 'tags': ['n'], 'word': 'sheilas'},
#  {'score': 20049265, 'tags': ['n'], 'word': 'beauties'},
#  {'score': 20049264, 'tags': ['n'], 'word': 'fems'},
#  {'score': 20049258, 'tags': ['n'], 'word': 'womenfolk'},
#  {'score': 20049256, 'tags': ['n'], 'word': 'people'},
#  {'score': 20049255, 'tags': ['n'], 'word': 'feminists'},
#  {'score': 20049253, 'tags': ['n'], 'word': 'husbands'},
#  {'score': 20049252, 'tags': ['n'], 'word': 'children'},
#  {'score': 20049251, 'tags': ['n'], 'word': 'menfolk'},
#  {'score': 20049249, 'tags': ['n'], 'word': 'boys'},
#  {'score': 20049248, 'tags': ['n'], 'word': 'males'},
#  {'score': 20049247, 'tags': ['n'], 'word': 'businesswomen'},
#  {'score': 20049246, 'tags': ['n'], 'word': 'moms'},
#  {'score': 20049245, 'tags': ['n'], 'word': 'womyn'},
#  {'score': 20049244, 'tags': ['n'], 'word': 'minorities'},
#  {'score': 20049243, 'tags': ['n'], 'word': 'daughters'},
#  {'score': 20049242, 'tags': ['n'], 'word': 'servicemen'},
#  {'score': 20049241, 'tags': ['n'], 'word': 'soldiers'},
#  {'score': 20049239, 'tags': ['n'], 'word': 'policewomen'},
#  {'score': 20049238, 'tags': ['n'], 'word': 'individuals'},
#  {'score': 20049237, 'tags': ['n'], 'word': 'teenagers'},
#  {'score': 20049236, 'tags': ['n', 'ant'], 'word': 'male'},
#  {'score': 20049235, 'tags': ['n'], 'word': 'youths'},
#  {'score': 20049234, 'tags': ['n'], 'word': 'girlfriends'},
#  {'score': 20049233, 'tags': ['n'], 'word': 'workers'},
#  {'score': 20049232, 'tags': ['n'], 'word': 'babies'},
#  {'score': 20049231, 'tags': ['n'], 'word': 'athletes'},
#  {'score': 20049230, 'tags': ['n'], 'word': 'grandmothers'},
#  {'score': 20049229, 'tags': ['n'], 'word': 'housewives'},
#  {'score': 20049228, 'tags': ['n'], 'word': 'noblewomen'},
#  {'score': 20049227, 'tags': ['n'], 'word': 'gays'},
#  {'score': 20049226, 'tags': ['n'], 'word': 'families'},
#  {'score': 20049225, 'tags': ['n'], 'word': 'citizens'},
#  {'score': 20049224, 'tags': ['n'], 'word': 'civilians'},
#  {'score': 20049223, 'tags': ['n'], 'word': 'mens'},
#  {'score': 20049222, 'tags': ['n'], 'word': 'widows'},
#  {'score': 20049221, 'tags': ['n'], 'word': 'blokes'},
#  {'score': 20049219, 'tags': ['n'], 'word': 'misogynists'},
#  {'score': 20049216, 'tags': ['n'], 'word': 'muslimah'},
#  {'score': 20049215, 'tags': ['n', 'prop'], 'word': 'amina'},
#  {'score': 20049214, 'tags': ['n', 'prop'], 'word': 'sumaya'},
#  {'score': 20049213, 'tags': ['n', 'v'], 'word': 'lady'},
#  {'score': 20049212, 'tags': ['n', 'prop'], 'word': 'zaynab'},
#  {'score': 20049211, 'tags': ['n', 'prop'], 'word': 'syeda'},
#  {'score': 20049210, 'tags': ['n', 'prop'], 'word': 'munira'},
#  {'score': 20049209, 'tags': ['n', 'prop'], 'word': 'fatima'},
#  {'score': 20049208, 'tags': ['n', 'prop'], 'word': 'khadija'},
#  {'score': 20049207, 'tags': ['n', 'prop'], 'word': 'joumana'},
#  {'score': 20049206, 'tags': ['n', 'prop'], 'word': 'huda'},
#  {'score': 20049205, 'tags': ['n', 'prop'], 'word': 'farah'},
#  {'score': 20049204, 'tags': ['n', 'prop'], 'word': 'sadiya'},
#  {'score': 20049203, 'tags': ['n'], 'word': 'first woman'},
#  {'score': 20049202, 'tags': ['n', 'prop'], 'word': 'anwar'},
#  {'score': 20049201, 'tags': ['n', 'prop'], 'word': 'suleika'},
#  {'score': 20049200, 'tags': ['n'], 'word': 'sofana'},
#  {'score': 20049199, 'tags': ['n'], 'word': 'sruti'},
#  {'score': 20049198, 'tags': ['n'], 'word': 'aliyha'},
#  {'score': 20049197, 'tags': ['n'], 'word': 'jinniyah'},
#  {'score': 20049196, 'tags': ['n', 'prop'], 'word': 'leila'},
#  {'score': 20049195, 'tags': ['n'], 'word': 'samaritaness'},
#  {'score': 20049194, 'tags': ['n', 'prop'], 'word': 'sarah'},
#  {'score': 20049193, 'tags': ['n', 'prop'], 'word': 'aisha'},
#  {'score': 20049192, 'tags': ['n'], 'word': 'shahidka'},
#  {'score': 20049191, 'tags': ['n'], 'word': 'tooba'},
#  {'score': 20049190, 'tags': ['n'], 'word': 'loujain'},
#  {'score': 20049189, 'tags': ['n'], 'word': 'sameen'},
#  {'score': 20049188, 'tags': ['n', 'prop'], 'word': 'soraya'},
#  {'score': 20049187, 'tags': ['n', 'prop'], 'word': 'mecca'},
#  {'score': 20049186, 'tags': ['n'], 'word': 'uroosa'},
#  {'score': 20049185, 'tags': ['n', 'prop'], 'word': 'ayesha'},
#  {'score': 20049184, 'tags': ['n', 'prop'], 'word': 'maryam'},
#  {'score': 20049183, 'tags': ['n'], 'word': 'aarah'},
#  {'score': 20049182, 'tags': ['n', 'prop'], 'word': 'sariyah'},
#  {'score': 20049181, 'tags': ['n'], 'word': 'two ladies name'},
#  {'score': 20049180, 'tags': ['n'], 'word': 'abeer'},
#  {'score': 20049179, 'tags': ['n'], 'word': 'awan'},
#  {'score': 20049178, 'tags': ['n', 'prop'], 'word': 'farrah'},
#  {'score': 20049177, 'tags': ['n'], 'word': 'ilham'},
#  {'score': 20049176, 'tags': ['n'], 'word': 'zohra'},
#  {'score': 20049175, 'tags': ['n'], 'word': 'noor'}]

# %%
type(response.json())
# Out:
# list

# %%
for obj in response.json():
    print(obj["word"])
# Out:
# female
# females
# femmes
# mujeres
# wives
# gals
# girls
# dames
# damsels
# ladies
# mothers
# sisters
# wenches
# heroines
# maidens
# lasses
# womankind
# matrons
# distaff
# chicks
# sheilas
# beauties
# fems
# womenfolk
# people
# feminists
# husbands
# children
# menfolk
# boys
# males
# businesswomen
# moms
# womyn
# minorities
# daughters
# servicemen
# soldiers
# policewomen
# individuals
# teenagers
# male
# youths
# girlfriends
# workers
# babies
# athletes
# grandmothers
# housewives
# noblewomen
# gays
# families
# citizens
# civilians
# mens
# widows
# blokes
# misogynists
# muslimah
# amina
# sumaya
# lady
# zaynab
# syeda
# munira
# fatima
# khadija
# joumana
# huda
# farah
# sadiya
# first woman
# anwar
# suleika
# sofana
# sruti
# aliyha
# jinniyah
# leila
# samaritaness
# sarah
# aisha
# shahidka
# tooba
# loujain
# sameen
# soraya
# mecca
# uroosa
# ayesha
# maryam
# aarah
# sariyah
# two ladies name
# abeer
# awan
# farrah
# ilham
# zohra
# noor

# %%
sinonime = []

for obj in response.json():
    sinonime.append(obj["word"])

# %%
print(sinonime)
# Out:
# ['female', 'females', 'femmes', 'mujeres', 'wives', 'gals', 'girls', 'dames', 'damsels', 'ladies', 'mothers', 'sisters', 'wenches', 'heroines', 'maidens', 'lasses', 'womankind', 'matrons', 'distaff', 'chicks', 'sheilas', 'beauties', 'fems', 'womenfolk', 'people', 'feminists', 'husbands', 'children', 'menfolk', 'boys', 'males', 'businesswomen', 'moms', 'womyn', 'minorities', 'daughters', 'servicemen', 'soldiers', 'policewomen', 'individuals', 'teenagers', 'male', 'youths', 'girlfriends', 'workers', 'babies', 'athletes', 'grandmothers', 'housewives', 'noblewomen', 'gays', 'families', 'citizens', 'civilians', 'mens', 'widows', 'blokes', 'misogynists', 'muslimah', 'amina', 'sumaya', 'lady', 'zaynab', 'syeda', 'munira', 'fatima', 'khadija', 'joumana', 'huda', 'farah', 'sadiya', 'first woman', 'anwar', 'suleika', 'sofana', 'sruti', 'aliyha', 'jinniyah', 'leila', 'samaritaness', 'sarah', 'aisha', 'shahidka', 'tooba', 'loujain', 'sameen', 'soraya', 'mecca', 'uroosa', 'ayesha', 'maryam', 'aarah', 'sariyah', 'two ladies name', 'abeer', 'awan', 'farrah', 'ilham', 'zohra', 'noor']
